# %% [markdown]
# # Serial Stock Prediction
#
#
# Stock Market Analysis and Prediction is the project on technical analysis, visualization and prediction using data provided by Google Finance. By looking at data from the stock market, particularly some giant technology stocks and others. Used pandas to get stock information, visualize different aspects of it, and finally looked at a few ways of analyzing the risk of a stock, based on its previous performance history. Predicted future stock prices through a machine learning model.

# %%
# Matplotlib for plotting in the notebook
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Import the Stocker Class

# %%
from stocker import Stocker

# %% [markdown]
# ### Instantiate a Stocker object
#
# We will be looking at Amazon stock data.

# %%
amazon = Stocker('AMZN')
# Out:
# AMZN Stocker Initialized. Data covers 1997-05-16 to 2018-03-27.

# %% [markdown]
# ### Basic Plot of Stock History
#
# We have a little over 20 years of Amazon price history.

# %%
amazon.plot_stock()
# Out:
# Maximum Adj. Close = 1598.39 on 2018-03-12.
# Minimum Adj. Close = 1.40 on 1997-05-22.
# Current Adj. Close = 1497.05 on 2018-03-27.

# %% [markdown]
# IT Looks predictable

# %% [markdown]
# ### Plot of Daily Changes

# %%
amazon.plot_stock(stats=['Daily Change'])
# Out:
# Maximum Daily Change = 81.38 on 2018-02-06.
# Minimum Daily Change = -79.20 on 2018-02-08.
# Current Daily Change = -75.35 on 2018-03-27.

# %% [markdown]
# There have been some extreme changes in absolute magnitude recently, but these are not as large as they seem because the price of the stock has increased. We could change the plot to have percentage change on the y-axis. There do not appear to be trends with regards to the changes in one direction or the other. However, we know the stock has increased in value, so the overall average daily change must be slightly positive.

# %% [markdown]
# ## Examine Trends/Patterns
#
# We can create a basic model (with no predictions) trained on the past 3 years of data to inspect any trends and patterns in the data.

# %%
model, model_data = amazon.create_prophet_model()

# %%
# Variables assigned from previous method call
model.plot_components(model_data)
plt.show()

# %% [markdown]
# ### Test Addition of a Weekly Seasonality
#
# Although it is unlikely, there might be a significant weekly component which would improve the model. Let's add it in and look at the pattern.

# %%
amazon.weekly_seasonality=True
model, model_data = amazon.create_prophet_model()

# %%
model.plot_components(model_data)
plt.show()

# %% [markdown]
# Maybe there is a slight weekly pattern? For now, we can remove that seasonality and then evaluate models with and without it to see the effect on predictions.

# %%
amazon.weekly_seasonality=False

# %% [markdown]
# # First Predictions
#
# We can make a prediction for any number of specified days using the create model method. The prediction also includes the uncertainty interval, a necessity when making estimates about the future.

# %%
model, model_data = amazon.create_prophet_model(days=90)
# Out:
# Predicted Price on 2018-06-25 = $1882.69

# %% [markdown]
# The model predicts a continuous increase in price. Notice how the model for both the past data and the future data is smoother than the actual observations. The model smooths out the noise on the small scale in order to make more accurate general predictions over a long period. In other words, an additive model will be more accurate at capturing general movements rather than specific daily fluctuations.

# %% [markdown]
# To quantify the accuracy of our predictions, we can find the average dollar error on both the testing and training data, the percentage the actual price was in the predicted confidence interval, and the percentage of times we predicted the correct direction for the stock.

# %%
amazon.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $1063.08.
# Actual price on    2018-03-23 = $1495.56.
#
# Average Absolute Error on Training Data = $16.27.
# Average Absolute Error on Testing  Data = $135.92.
#
# When the model predicted an increase, the price increased 57.76% of the time.
# When the model predicted a  decrease, the price decreased  42.53% of the time.
#
# The actual value was within the 80% confidence interval 65.06% of the time.

# %% [markdown]
# # Changepoint Prior Scale Selection
#
# Changepoints represent where a time series goes from increasing to decreasing or from increasing slowly to increasingly rapidly.
# The changepoint prior scale represents the amount of weight given to the changepoints in the model. This can be used to control overfitting vs underfitting.

# %% [markdown]
# ## Graphical Comparison
#
# We will start with a range of four priors to compare.

# %%
amazon.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])

# %% [markdown]
# ## Quantitative Comparison
#
# This gives us an idea of how well each prior fits the training data, but no numbers to back up our intuitions. The changepoint prior validation method is designed to provide numerical backing.  The model will be trained on the three years prior to the validation period.

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# Validation Range 2016-01-04 to 2017-01-03.
#
#      cps  train_err  train_range    test_err  test_range
# 0  0.001  44.476286   153.071464  149.378762  152.252630
# 1  0.050  11.225187    35.889621  148.769640  137.840244
# 2  0.100  10.710383    34.591252  149.751968  181.374881
# 3  0.200   9.810689    32.132914  126.039086  306.610262

# %% [markdown]
# The test error decreases as we increase the prior. Stocks change considerably on a day to day basis, and a more flexible model can account for these fluctuations.

# %% [markdown]
# ### Refine Search
#
# We can evaluate additional changepoint prior scales to determine the best fit for our data.

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.15, 0.2, 0.25,0.4, 0.5, 0.6])
# Out:
# Validation Range 2016-01-04 to 2017-01-03.
#
#     cps  train_err  train_range    test_err  test_range
# 0  0.15  10.349379    33.525031  146.166050  216.018452
# 1  0.20   9.810689    32.109333  126.039086  310.985776
# 2  0.25   9.378231    31.010799  110.433461  448.740073
# 3  0.40   8.569736    28.865367   72.118846  753.356879
# 4  0.50   8.359124    28.284270   74.421845  895.847108
# 5  0.60   8.267228    28.076240   77.989126  960.682389

# %%
amazon.changepoint_prior_scale = 0.5

# %% [markdown]
# ### Evaluate Improved Model

# %%
amazon.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $1002.10.
# Actual price on    2018-03-23 = $1495.56.
#
# Average Absolute Error on Training Data = $10.89.
# Average Absolute Error on Testing  Data = $175.86.
#
# When the model predicted an increase, the price increased 59.73% of the time.
# When the model predicted a  decrease, the price decreased  45.45% of the time.
#
# The actual value was within the 80% confidence interval 83.13% of the time.

# %% [markdown]
# #### Add in weekly seasonality and evaluate

# %%
amazon.weekly_seasonality=True

# %%
amazon.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $973.95.
# Actual price on    2018-03-23 = $1495.56.
#
# Average Absolute Error on Training Data = $10.83.
# Average Absolute Error on Testing  Data = $180.52.
#
# When the model predicted an increase, the price increased 61.33% of the time.
# When the model predicted a  decrease, the price decreased  47.96% of the time.
#
# The actual value was within the 80% confidence interval 85.14% of the time.

# %% [markdown]
# The best changepoint prior scale for our model is 0.5 and including the weekly seasonality did not improve the model. Therefore, we will change these settings accordingly.

# %%
amazon.changepoint_prior_scale=0.5
amazon.weekly_seasonality=True

# %% [markdown]
# ## Play the Daily Market
#
# We will compare our model with the simple strategy of buying and holding over the same time period. The rules of our game are straightforward:
#
# 1. If we predict the price will increase, we buy stock on that day. If we predict a decrease, we do not play the market.
# 2. If we predicted an increase and the stock does increase, we recieve the change in price of the stock over that day times the number of shares.
# 3. If we predicted an increase and the stock decreases, we lose the change in price of the stock over that day times the number of shares.

# %%
amazon.evaluate_prediction(nshares=1000)
# Out:
# You played the stock market in AMZN from 2017-03-27 to 2018-03-27 with 1000 shares.
#
# When the model predicted an increase, the price increased 61.33% of the time.
# When the model predicted a  decrease, the price decreased  47.96% of the time.
#
# The total profit using the Prophet model = $564950.00.
# The Buy and Hold strategy profit =         $648740.00.
#
# Thanks for playing the stock market!

# %% [markdown]
# Our profits do not depend on the difference between the final predicted price and the actual price, only on the percentage of the time we correctly predicted the direction.

# %% [markdown]
# #### Try a Different Period
#
# We can evaluate any time period we like to see if there are times when we beat the buy and hold strategy.

# %%
amazon.evaluate_prediction(start_date = '2008-01-03', end_date = '2009-01-05', nshares=1000)
# Out:
# You played the stock market in AMZN from 2008-01-03 to 2009-01-05 with 1000 shares.
#
# When the model predicted an increase, the price increased 42.69% of the time.
# When the model predicted a  decrease, the price decreased  53.75% of the time.
#
# The total profit using the Prophet model = $-42230.00.
# The Buy and Hold strategy profit =         $-43930.00.
#
# Thanks for playing the stock market!

# %% [markdown]
# # Predict the Future
#
# We can predict any number of days into the future. This function automatically trains on the past 3 years and makes predictions with the uncertainty intervals.

# %%
amazon.predict_future(days=10)
# Out:
# Predicted Increase:
#
#          Date     estimate     change        upper        lower
# 1  2018-03-28  1577.180099   2.994918  1599.438124  1556.538748
# 2  2018-03-29  1579.809845   2.629746  1603.087591  1558.459297
# 3  2018-03-30  1586.577626   6.767781  1608.441121  1565.829041
# 5  2018-04-01  1627.850670  41.273044  1649.577060  1605.408980
# 8  2018-04-04  1602.921998   1.159360  1625.710197  1580.210771
# 9  2018-04-05  1605.569502   2.647505  1626.227540  1583.564773
# 10 2018-04-06  1612.697836   7.128334  1635.249202  1590.074918
#
# Predicted Decrease:
#
#         Date     estimate     change        upper        lower
# 6 2018-04-02  1601.864016 -25.986654  1623.054256  1579.831131
# 7 2018-04-03  1601.762638  -0.101379  1623.986548  1580.357141

# %%
amazon.predict_future(days=100)
# Out:
# Predicted Increase:
#
#          Date     estimate     change        upper        lower
# 1  2018-03-28  1577.180099   2.994918  1597.747725  1555.883672
# 2  2018-03-29  1579.809845   2.629746  1602.552049  1558.381764
# 3  2018-03-30  1586.577626   6.767781  1609.013146  1565.466799
# 5  2018-04-01  1627.850670  41.273044  1647.129460  1606.127781
# 8  2018-04-04  1602.921998   1.159360  1625.484832  1582.090993
# 9  2018-04-05  1605.569502   2.647505  1630.405951  1583.328867
# 10 2018-04-06  1612.697836   7.128334  1635.331221  1591.677151
# 2 1986-03-17  29.00  29.75  29.0  29.50   462400.0          0.0          1.0
# 3 1986-03-18  29.50  29.75  28.5  28.75   235300.0          0.0          1.0
# 4 1986-03-19  28.75  29.00  28.0  28.25   166300.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close   Adj. Volume         ds  \
# 0   0.058941   0.067609  0.058941    0.064720  1.031789e+09 1986-03-13
# 1   0.064720   0.068187  0.064720    0.067031  3.081600e+08 1986-03-14
# 2   0.067031   0.068765  0.067031    0.068187  1.331712e+08 1986-03-17
# 3   0.068187   0.068765  0.065876    0.066454  6.776640e+07 1986-03-18
# 4   0.066454   0.067031  0.064720    0.065298  4.789440e+07 1986-03-19
#
#           y  Daily Change
# 0  0.064720      0.005779
# 1  0.067031      0.002311
# 2  0.068187      0.001156
# 3  0.066454     -0.001734
# 4  0.065298     -0.001156

# %%
microsoft.plot_stock()
# Out:
# Maximum Adj. Close = 96.77 on 2018-03-12.
# Minimum Adj. Close = 0.06 on 1986-03-24.
# Current Adj. Close = 89.47 on 2018-03-27.

# %%
microsoft.plot_stock(start_date = '2000-01-07', end_date = '2018-01-18', 
                     stats = ['Daily Change', 'Adj. Volume'], plot_type='pct')
# Out:
# Maximum Daily Change = 2.08 on 2008-10-13.
# Minimum Daily Change = -3.34 on 2017-12-04.
# Current Daily Change = -5.47 on 2018-03-27.
#
# Maximum Adj. Volume = 591052200.00 on 2006-04-28.
# Minimum Adj. Volume = 7425503.00 on 2017-11-24.
# Current Adj. Volume = 53704562.00 on 2018-03-27.

# %%
microsoft.buy_and_hold(start_date='1986-03-13', end_date='2018-01-16', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1986-03-13 to 2018-01-16 for 100 shares = $8829.11

# %%
microsoft.buy_and_hold(start_date='1999-01-05', end_date='2002-01-03', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1999-01-05 to 2002-01-03 for 100 shares = $-56.92

# %%
model, model_data = microsoft.create_prophet_model()

# %%
model.plot_components(model_data)
plt.show()

# %%
print(microsoft.weekly_seasonality)
microsoft.weekly_seasonality = True
print(microsoft.weekly_seasonality)
# Out:
# False
# True

# %%
model, model_data = microsoft.create_prophet_model(days=0)

# %%
model.plot_components(model_data)
plt.show()

# %%
microsoft.weekly_seasonality=False

# %%
microsoft.changepoint_date_analysis()
# Out:
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 361 2016-09-01   55.966886 -1.363753
# 169 2015-11-27   51.353167 -1.115812
# 289 2016-05-20   48.886934  0.884024
# 120 2015-09-18   41.122995  0.554914
# 506 2017-03-31   64.816957  0.540252

# %%
model, future = microsoft.create_prophet_model(days=180)
# Out:
# Predicted Price on 2018-09-23 = $105.09

# %%
microsoft.evaluate_prediction(nshares=1000)
# Out:
# You played the stock market in MSFT from 2017-03-27 to 2018-03-27 with 1000 shares.
#
# When the model predicted an increase, the price increased 55.93% of the time.
# When the model predicted a  decrease, the price decreased  41.67% of the time.
#
# The total profit using the Prophet model = $12827.42.
# The Buy and Hold strategy profit =         $23111.01.
#
# Thanks for playing the stock market!
